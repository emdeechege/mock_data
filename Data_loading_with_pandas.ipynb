# %%
import requests

# %%
data_url = "https://raw.githubusercontent.com/emdeechege/mock_data/refs/heads/master/student_mock_data.json"

# %%
student_data = requests.get(data_url)

# %%
student_data_json = student_data.json()

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.7 MB 493 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 19.8 MB 1.8 MB/s eta 0:00:01
# ...

# %%
import pandas

# %%
df = pandas.DataFrame(student_data_json)

# %%
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 250 kB 616 kB/s eta 0:00:01
# ...

# %%
 df.to_excel('students_data.xlsx')

# %%
df.to_csv('students_data_csv')
